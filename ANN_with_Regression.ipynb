# %% [markdown]
# <a href="https://colab.research.google.com/github/mrrkdas/LazyProgrammer-DeepLearning-Course/blob/main/ANN_with_Regression.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import tensorflow as tf
import numpy as np
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D

# %% [markdown]
# ## Data (Copied and pasted from notebook)

# %%
# Make the dataset
N = 1000
X = np.random.random((N, 2)) * 6 - 3 # uniformly distributed between (-3, +3)
y = np.cos(2*X[:,0]) + np.cos(3*X[:,1])

# %%
# Plot it
fig = plt.figure()
ax = fig.add_subplot(111, projection='3d')
ax.scatter(X[:,0], X[:,1], Y)
# plt.show()

# %% [markdown]
# ## Model (not copied and pasted)

# %%
from tensorflow.keras.layers import Input, Dense
from tensorflow.keras.models import Model

# I will be using the funtional API
input = Input((2,))

dense = Dense(128, activation = 'relu')

x = dense(input)

output = Dense(1) (x)

# %%
model = Model(input, output)

# %%
model.compile(loss = 'mse', optimizer = 'adam')

# %%
r = model.fit(X, y, epochs = 100)
# Out:
# Epoch 1/100
# 32/32 [==============================] - 0s 973us/step - loss: 0.9730
# Epoch 2/100
# 32/32 [==============================] - 0s 964us/step - loss: 0.9427
# Epoch 3/100
# 32/32 [==============================] - 0s 1ms/step - loss: 0.9328
# Epoch 4/100
# 32/32 [==============================] - 0s 1ms/step - loss: 0.9214
# Epoch 5/100
# 32/32 [==============================] - 0s 1ms/step - loss: 0.9164
# Epoch 6/100
# 32/32 [==============================] - 0s 1ms/step - loss: 0.9141
# Epoch 7/100
# 32/32 [==============================] - 0s 1ms/step - loss: 0.9065
# Epoch 8/100
# 32/32 [==============================] - 0s 1ms/step - loss: 0.9016
# Epoch 9/100
# 32/32 [==============================] - 0s 6ms/step - loss: 0.8983
# Epoch 10/100
# 32/32 [==============================] - 0s 4ms/step - loss: 0.8945
# Epoch 11/100
# 32/32 [==============================] - 0s 2ms/step - loss: 0.8953
# Epoch 12/100
# ...

# %%
plt.plot(r.history['loss'])

# %% [markdown]
# ## Copied Visualization code

# %%
# Plot the prediction surface
fig = plt.figure()
ax = fig.add_subplot(111, projection='3d')
ax.scatter(X[:,0], X[:,1], Y)

# surface plot
line = np.linspace(-3, 3, 50)
xx, yy = np.meshgrid(line, line)
Xgrid = np.vstack((xx.flatten(), yy.flatten())).T
Yhat = model.predict(Xgrid).flatten()
ax.plot_trisurf(Xgrid[:,0], Xgrid[:,1], Yhat, linewidth=0.2, antialiased=True)
plt.show()

# %%
# Can it extrapolate?
# Plot the prediction surface
fig = plt.figure()
ax = fig.add_subplot(111, projection='3d')
ax.scatter(X[:,0], X[:,1], Y)

# surface plot
line = np.linspace(-5, 5, 50)
xx, yy = np.meshgrid(line, line)
Xgrid = np.vstack((xx.flatten(), yy.flatten())).T
Yhat = model.predict(Xgrid).flatten()
ax.plot_trisurf(Xgrid[:,0], Xgrid[:,1], Yhat, linewidth=0.2, antialiased=True)
plt.show()
